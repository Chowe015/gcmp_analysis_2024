# %% [markdown]
# # Benfords Law Analysis
# ## Overview
# This notebook contains code for fitting Benford's Law to data.

# %% [markdown]
# ## Define a function for getting first digits from a list of numbers.
# First we setup a test example for extracting first digits.

# %%
test_numbers = [0.1, 4.5, 5.6, 4.5, 5.8]
expected_results = [0, 4, 5, 4, 5]
print(f"expected results: {expected_results}")
# Out:
# expected results: [0, 4, 5, 4, 5]

# %%
def get_first_digits (list_of_numbers):
    """ return the first digits of list numbers
    """
    result = []
    print(list_of_numbers)
    ## my code of numbers
    for number in list_of_numbers:
        #convert the number to string to get the first digit
        first_digit= int(str(number)[0])
        result.append(first_digit)
    return result

# To test the function
output = get_first_digits(test_numbers)

print(f"expected results are {expected_results}")
print(f"observed results are {output}")
# Out:
# [0.1, 4.5, 5.6, 4.5, 5.8]
# expected results are [0, 4, 5, 4, 5]
# observed results are [0, 4, 5, 4, 5]

# %%
first_digits = get_first_digits(test_numbers)
first_digits
# Out:
# [0.1, 4.5, 5.6, 4.5, 5.8]
# [0, 4, 5, 4, 5]

# %% [markdown]
# ## Define a function to calculate the frequency of the first digits

# %%
def frequency_fdigits (first_digits):
    """ frequency of the first digits as a dictionary
    first digits == a list of first digits
    """
    print(f"the first digits are {first_digits}")

    frequency_results = {}
    
    for first_digit in first_digits:
        print(first_digit)
        count_fdigit = first_digits.count(first_digit)
        print(f"count of the first digit {count_fdigit}")
        length_of_list = len(first_digits)
        frequency = count_fdigit/length_of_list
        print(frequency)
        frequency_results[first_digit] = frequency

    return frequency_results

#getting output frequency of fdigits

output = frequency_fdigits(first_digits)
print(output)
# Out:
# the first digits are [0, 4, 5, 4, 5]
# 0
# count of the first digit 1
# 0.2
# 4
# count of the first digit 2
# 0.4
# 5
# count of the first digit 2
# 0.4
# 4
# count of the first digit 2
# 0.4
# 5
# count of the first digit 2
# 0.4
# {0: 0.2, 4: 0.4, 5: 0.4}

# %%
expected_result = {0:1/5, 4:2/5, 5:2/5}
print(expected_result)
# Out:
# {0: 0.2, 4: 0.4, 5: 0.4}

# %% [markdown]
# ## Plot observed verses expected digit frequencies

# %%
import pandas as pd
import numpy as np

# Expected frequency results based on Benford's Law
def benfords_law():
    return {digit: np.log10(1 + 1/digit) for digit in range(1, 10)}

# Compare observed results to Benford's Law
observed_frequency = frequency_fdigits(first_digits)
benford_frequency = benfords_law()

print(f"Benford's Law frequency results: {benford_frequency}")

# Plotting the results
def plot_frequencies(observed, expected):
    digits = range(1, 10)
    observed_values = [observed.get(digit, 0) for digit in digits]
    expected_values = [expected.get(digit) for digit in digits]
    
    plt.figure(figsize=(10, 6))
    plt.bar(digits, observed_values, alpha=0.5, label='Observed')
    plt.plot(digits, expected_values, 'r-', marker='o', label='Expected (Benford\'s Law)')
    plt.xlabel('First Digit')
    plt.ylabel('Frequency')
    plt.title('First Digit Frequency Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_frequencies(observed_frequency, benford_frequency)
# Out:
# expected results: [1, 4, 5, 4, 5]
# expected results are [1, 4, 5, 4, 5]
# observed results are [1, 4, 5, 4, 5]
# Frequency of first digits: {1: 0.2, 4: 0.4, 5: 0.4}
# Benford's Law frequency results: {1: 0.3010299956639812, 2: 0.17609125905568124, 3: 0.12493873660829993, 4: 0.09691001300805642, 5: 0.07918124604762482, 6: 0.06694678963061322, 7: 0.05799194697768673, 8: 0.05115252244738129, 9: 0.04575749056067514}

# %%
from numpy import log10

def benfords_law():
    """returns first digits frequency as a dict


    
    """
    
    freqs = {}
    for number in range(1,10):
        print(f"number one to ten {number}")
        result = log10(1 + 1/number)
        print(result)
        freqs[number] = result
    return freqs

benfords_law()
# Out:
# number one to ten 1
# 0.3010299956639812
# number one to ten 2
# 0.17609125905568124
# number one to ten 3
# 0.12493873660829993
# number one to ten 4
# 0.09691001300805642
# number one to ten 5
# 0.07918124604762482
# number one to ten 6
# 0.06694678963061322
# number one to ten 7
# 0.05799194697768673
# number one to ten 8
# 0.05115252244738129
# number one to ten 9
# 0.04575749056067514
# {1: 0.3010299956639812,
#  2: 0.17609125905568124,
#  3: 0.12493873660829993,
#  4: 0.09691001300805642,
#  5: 0.07918124604762482,
#  6: 0.06694678963061322,
#  7: 0.05799194697768673,
#  8: 0.05115252244738129,
#  9: 0.04575749056067514}

# %%
from matplotlib.pyplot import scatter, boxplot, xlabel, ylabel
x = [0, 4, 5, 4, 5]
y = [0, 1, 2, 3, 4]
length_of_x = len(x)
length_of_y = len(y)
print(f"we have {length_of_x} xvalues, and {length_of_y} yvalues to plot")
scatter(x,y)
xlabel("test_numbers")
ylabel("frequency")
# Out:
# we have 5 xvalues, and 5 yvalues to plot
# Text(0, 0.5, 'frequency')
